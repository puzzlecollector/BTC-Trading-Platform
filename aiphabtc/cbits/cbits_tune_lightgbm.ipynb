# %%
# !nvidia-smi
# Out:
# Sat Jul  1 11:42:56 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    50W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import pandas as pd
import numpy as np
import os

chart_df = pd.read_csv("/content/drive/MyDrive/chart_with_sentiment_scores.csv")

# %%
# add technical indicators
import pandas_ta as ta
from tqdm.auto import tqdm
hours, days, months = [], [], []
for dt in tqdm(chart_df["datetime"]):
  dtobj = pd.to_datetime(dt)
  hours.append(dtobj.hour)
  days.append(dtobj.day)
  months.append(dtobj.month)

chart_df["hours"] = hours
chart_df["days"] = days
chart_df["months"] = months

chart_df["ebsw"] = chart_df.ta.ebsw(lookahead=False)
chart_df["cmf"] = chart_df.ta.cmf(lookahead=False)
chart_df["bop"] = chart_df.ta.bop(lookahead=False)
chart_df["rsi/100"] = chart_df.ta.rsi(lookahead=False) / 100.0
chart_df["hwma"] = chart_df.ta.hwma(lookahead=False)
chart_df["linreg"] = chart_df.ta.linreg(lookahead=False)
chart_df["hwma/close"] = chart_df["hwma"] / chart_df["close"]
chart_df["linreg/close"] = chart_df["linreg"] / chart_df["close"]
chart_df["high/low"] = chart_df["high"] / chart_df["low"]
chart_df["high/open"] = chart_df["high"] / chart_df["open"]
chart_df["low/open"] = chart_df["low"] / chart_df["open"]
chart_df["close/open"] = chart_df["close"] / chart_df["open"]
chart_df["high/close"] = chart_df["high"] / chart_df["close"]
chart_df["low/close"]  = chart_df["low"] / chart_df["close"]

for l in range(1, 6):
  for col in ["open", "high", "low", "close", "volume"]:
    val = chart_df[col].values
    val_ret = [None for _ in range(l)]
    for i in range(l, len(val)):
      if val[i-l] == 0:
        ret = 1
      else:
        ret = val[i] / val[i-l]
      val_ret.append(ret)
    chart_df[f"{col}_change_{l}"] = val_ret

chart_df = chart_df.drop(columns={"datetime", "open", "high", "low", "close", "volume", "linreg", "hwma"})
# Out:
#   0%|          | 0/9335 [00:00<?, ?it/s]

# %%
chart_df.dropna(inplace=True)

# %%
chart_df.head()
# Out:
#     targets  news_positive_scores  news_negative_scores  hours  days  months  \
# 39      2.0              0.000000              0.000000      4     1       4
# 40      2.0              0.000000              0.000000      8     1       4
# 41      2.0             13.904989              8.095011     12     1       4
# 42      2.0              8.305100              3.694901     16     1       4
# 43      0.0              8.310017              6.689983     20     1       4
#
#         ebsw       cmf       bop   rsi/100  ...  open_change_4  high_change_4  \
# 39  0.000000  0.221446 -0.045573  0.659537  ...       1.004453       1.007434
# 40  0.577350  0.201553 -0.005917  0.658919  ...       1.007774       1.006996
# 41  0.796874  0.172388  0.514761  0.690842  ...       1.005480       1.011357
# 42  0.983671  0.021719 -0.328696  0.659900  ...       1.010377       1.003634
# 43  0.986626  0.075315  0.291923  0.674547  ...       1.002053       1.002638
#
#     low_change_4  close_change_4  volume_change_4  open_change_5  \
# 39      1.006192        1.007774         1.143676       1.010897
# 40      1.003691        1.005484         1.730719       1.004198
# 41      1.006952        1.010020         3.140040       1.007732
# 42      1.016228        1.001828         0.437554       1.009456
# 43      1.003106        1.003805         0.600674       1.008761
#
#     high_change_5  low_change_5  close_change_5  volume_change_5
# 39       1.006783      1.008813        1.004198         1.477008
# 40       1.006005      1.003780        1.007735         1.223106
# 41       1.011994      1.007534        1.009474         2.201117
# 42       1.010700      1.008450        1.008163         2.220246
# 43       1.003386      1.016425        1.003550         0.273292
#
# [5 rows x 43 columns]

# %%
train_columns = []

for col in chart_df.columns:
  if col != "targets":
    train_columns.append(col)

X = chart_df[train_columns]
Y = chart_df["targets"]

# %%
import warnings

# Disable all user warnings
warnings.filterwarnings("ignore")

# %%
import optuna
import lightgbm as lgb
from sklearn.metrics import accuracy_score
from sklearn.model_selection import TimeSeriesSplit

def objective(trial):
  params = {
      "objective": "multiclass",
      "num_class": 3,
      "metric": "multi_logloss",
      "boosting_type": "gbdt",
      "num_leaves": trial.suggest_int("num_leaves", 10, 100),
      "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.1),
      "max_depth": trial.suggest_int("max_depth", 3, 10),
      "min_child_samples": trial.suggest_int("min_child_samples", 1, 20),
      "subsample": trial.suggest_float("subsample", 0.5, 1.0),
      "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
      "reg_alpha": trial.suggest_float("reg_alpha", 0, 1),
      "reg_lambda": trial.suggest_float("reg_lambda", 0, 1),
      "random_state": 42,
      "n_estimators": trial.suggest_int("n_estimators", 50, 5000)
  }
  tscv = TimeSeriesSplit(n_splits=5)
  accuracies = []
  for train_idx, val_idx in tscv.split(X):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    Y_train, Y_val = Y.iloc[train_idx], Y.iloc[val_idx]
    model = lgb.LGBMClassifier(**params)
    model.fit(X_train, Y_train, eval_set=[(X_val, Y_val)], verbose=False)
    Y_pred = model.predict(X_val)
    accuracy = accuracy_score(Y_val, Y_pred)
    accuracies.append(accuracy)
  return sum(accuracies) / len(accuracies)
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)
best_params = study.best_params
print(f"Best Parameters: {best_params}")
# Out:
# [I 2023-07-01 12:00:00,324] A new study created in memory with name: no-name-12c58db1-7ae1-47c6-82f3-e7dfdacd2786
# [I 2023-07-01 12:00:53,742] Trial 0 finished with value: 0.45823111684958046 and parameters: {'num_leaves': 26, 'learning_rate': 0.04464018917014528, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.6922439695596225, 'colsample_bytree': 0.9759518564239358, 'reg_alpha': 0.7505837717488202, 'reg_lambda': 0.15478221137444248, 'n_estimators': 4695}. Best is trial 0 with value: 0.45823111684958046.
# [I 2023-07-01 12:01:45,063] Trial 1 finished with value: 0.45668173014848285 and parameters: {'num_leaves': 91, 'learning_rate': 0.057009116148804106, 'max_depth': 4, 'min_child_samples': 1, 'subsample': 0.5486075620905257, 'colsample_bytree': 0.8629080866814253, 'reg_alpha': 0.1021467823184995, 'reg_lambda': 0.5868171965520286, 'n_estimators': 4246}. Best is trial 0 with value: 0.45823111684958046.
# [I 2023-07-01 12:01:52,931] Trial 2 finished with value: 0.46468689477081987 and parameters: {'num_leaves': 100, 'learning_rate': 0.0266314133696677, 'max_depth': 3, 'min_child_samples': 15, 'subsample': 0.5913782023728151, 'colsample_bytree': 0.8148838722605676, 'reg_alpha': 0.3994214559716508, 'reg_lambda': 0.4129767394913233, 'n_estimators': 692}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:02:54,523] Trial 3 finished with value: 0.4588766946417044 and parameters: {'num_leaves': 43, 'learning_rate': 0.04501103999540008, 'max_depth': 9, 'min_child_samples': 13, 'subsample': 0.9019019813822486, 'colsample_bytree': 0.9762598325534346, 'reg_alpha': 0.26782652670309537, 'reg_lambda': 0.905599171838913, 'n_estimators': 3673}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:04:40,576] Trial 4 finished with value: 0.4568108457069077 and parameters: {'num_leaves': 56, 'learning_rate': 0.01687759179895625, 'max_depth': 8, 'min_child_samples': 8, 'subsample': 0.7223681425332944, 'colsample_bytree': 0.8530628610569264, 'reg_alpha': 0.760447651310455, 'reg_lambda': 0.2256673182200135, 'n_estimators': 4915}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:05:03,275] Trial 5 finished with value: 0.45693996126533243 and parameters: {'num_leaves': 34, 'learning_rate': 0.03798030258197142, 'max_depth': 6, 'min_child_samples': 9, 'subsample': 0.7715510744993999, 'colsample_bytree': 0.7255216611772943, 'reg_alpha': 0.62000459289144, 'reg_lambda': 0.013854048972237853, 'n_estimators': 997}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:05:58,663] Trial 6 finished with value: 0.45939315687540344 and parameters: {'num_leaves': 66, 'learning_rate': 0.04292599313748823, 'max_depth': 9, 'min_child_samples': 18, 'subsample': 0.7907809262446921, 'colsample_bytree': 0.5567717772685038, 'reg_alpha': 0.19692765018483083, 'reg_lambda': 0.33708081717604843, 'n_estimators': 3466}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:06:28,762] Trial 7 finished with value: 0.45952227243382826 and parameters: {'num_leaves': 70, 'learning_rate': 0.08658446580782417, 'max_depth': 6, 'min_child_samples': 14, 'subsample': 0.6180594310983554, 'colsample_bytree': 0.5572107045877461, 'reg_alpha': 0.2352955694742539, 'reg_lambda': 0.7211421633131467, 'n_estimators': 2992}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:07:18,565] Trial 8 finished with value: 0.46016785022595225 and parameters: {'num_leaves': 93, 'learning_rate': 0.04613174163754801, 'max_depth': 7, 'min_child_samples': 9, 'subsample': 0.5273436446865825, 'colsample_bytree': 0.6515044917269829, 'reg_alpha': 0.2628640262954235, 'reg_lambda': 0.5367922117442493, 'n_estimators': 3172}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:08:11,554] Trial 9 finished with value: 0.45693996126533243 and parameters: {'num_leaves': 41, 'learning_rate': 0.08926028212195082, 'max_depth': 7, 'min_child_samples': 7, 'subsample': 0.7912912947889882, 'colsample_bytree': 0.9946134027132191, 'reg_alpha': 0.03614234283976103, 'reg_lambda': 0.6838743720573638, 'n_estimators': 1928}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:08:12,290] Trial 10 finished with value: 0.43524854744996777 and parameters: {'num_leaves': 12, 'learning_rate': 0.010116880983979764, 'max_depth': 3, 'min_child_samples': 19, 'subsample': 0.9946034099245764, 'colsample_bytree': 0.7860077229557139, 'reg_alpha': 0.9747708248768922, 'reg_lambda': 0.44303135292672746, 'n_estimators': 82}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:08:48,648] Trial 11 finished with value: 0.45836023240800516 and parameters: {'num_leaves': 100, 'learning_rate': 0.02645974001554571, 'max_depth': 5, 'min_child_samples': 14, 'subsample': 0.5026310117156064, 'colsample_bytree': 0.676146869606309, 'reg_alpha': 0.41060999772166856, 'reg_lambda': 0.454358217298909, 'n_estimators': 2082}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:08:58,946] Trial 12 finished with value: 0.4631375080697223 and parameters: {'num_leaves': 84, 'learning_rate': 0.029313588173061605, 'max_depth': 3, 'min_child_samples': 12, 'subsample': 0.5924090849717316, 'colsample_bytree': 0.6232856009795895, 'reg_alpha': 0.42466553556885966, 'reg_lambda': 0.5241100739915023, 'n_estimators': 1197}. Best is trial 2 with value: 0.46468689477081987.
# [I 2023-07-01 12:09:07,928] Trial 13 finished with value: 0.46481601032924463 and parameters: {'num_leaves': 80, 'learning_rate': 0.02558256543183074, 'max_depth': 3, 'min_child_samples': 16, 'subsample': 0.6227958235982818, 'colsample_bytree': 0.5012551610823455, 'reg_alpha': 0.43775261475082256, 'reg_lambda': 0.3410434930659435, 'n_estimators': 982}. Best is trial 13 with value: 0.46481601032924463.
# [I 2023-07-01 12:09:10,699] Trial 14 finished with value: 0.4703679793415107 and parameters: {'num_leaves': 79, 'learning_rate': 0.022637357938205545, 'max_depth': 4, 'min_child_samples': 17, 'subsample': 0.6426293766187743, 'colsample_bytree': 0.5059079188227772, 'reg_alpha': 0.4953542748971303, 'reg_lambda': 0.33729979112242053, 'n_estimators': 292}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:09:12,719] Trial 15 finished with value: 0.460942543576501 and parameters: {'num_leaves': 77, 'learning_rate': 0.012137249429401822, 'max_depth': 5, 'min_child_samples': 17, 'subsample': 0.6695118562283183, 'colsample_bytree': 0.5029591883285796, 'reg_alpha': 0.5182830885509173, 'reg_lambda': 0.331936360832808, 'n_estimators': 128}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:09:31,426] Trial 16 finished with value: 0.4631375080697224 and parameters: {'num_leaves': 61, 'learning_rate': 0.021230293540634167, 'max_depth': 4, 'min_child_samples': 16, 'subsample': 0.6523320633819912, 'colsample_bytree': 0.5187735805267759, 'reg_alpha': 0.5447673979903187, 'reg_lambda': 0.24452183279075954, 'n_estimators': 1755}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:09:40,363] Trial 17 finished with value: 0.4606843124596514 and parameters: {'num_leaves': 78, 'learning_rate': 0.06027396678921344, 'max_depth': 4, 'min_child_samples': 20, 'subsample': 0.6282747344858274, 'colsample_bytree': 0.5876419845971448, 'reg_alpha': 0.3549375442281422, 'reg_lambda': 0.11992984076441887, 'n_estimators': 633}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:10:22,838] Trial 18 finished with value: 0.45642349903163326 and parameters: {'num_leaves': 73, 'learning_rate': 0.03347363788639811, 'max_depth': 5, 'min_child_samples': 11, 'subsample': 0.7085427122451294, 'colsample_bytree': 0.6131257181496235, 'reg_alpha': 0.5817173866633907, 'reg_lambda': 0.33096020793964925, 'n_estimators': 2515}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:11:09,121] Trial 19 finished with value: 0.46016785022595225 and parameters: {'num_leaves': 50, 'learning_rate': 0.021472881915266973, 'max_depth': 10, 'min_child_samples': 17, 'subsample': 0.5715903376204631, 'colsample_bytree': 0.507880096437803, 'reg_alpha': 0.6450833015955146, 'reg_lambda': 0.021464279677387232, 'n_estimators': 1418}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:11:13,721] Trial 20 finished with value: 0.46920593931568755 and parameters: {'num_leaves': 83, 'learning_rate': 0.016733959483188184, 'max_depth': 4, 'min_child_samples': 20, 'subsample': 0.6464363467669985, 'colsample_bytree': 0.5537914852914804, 'reg_alpha': 0.48682365473979483, 'reg_lambda': 0.23801917301226028, 'n_estimators': 495}. Best is trial 14 with value: 0.4703679793415107.
# [I 2023-07-01 12:11:20,666] Trial 21 finished with value: 0.470755326016785 and parameters: {'num_leaves': 85, 'learning_rate': 0.016480067774555508, 'max_depth': 4, 'min_child_samples': 20, 'subsample': 0.6522429758963203, 'colsample_bytree': 0.556537269009522, 'reg_alpha': 0.48081704384119817, 'reg_lambda': 0.2582839736962967, 'n_estimators': 451}. Best is trial 21 with value: 0.470755326016785.
# [I 2023-07-01 12:11:24,857] Trial 22 finished with value: 0.4715300193673338 and parameters: {'num_leaves': 88, 'learning_rate': 0.010048104312153895, 'max_depth': 4, 'min_child_samples': 20, 'subsample': 0.6639761639712144, 'colsample_bytree': 0.5596357446499057, 'reg_alpha': 0.5005323592383311, 'reg_lambda': 0.23594539625107866, 'n_estimators': 399}. Best is trial 22 with value: 0.4715300193673338.
# [I 2023-07-01 12:11:30,602] Trial 23 finished with value: 0.47023886378308594 and parameters: {'num_leaves': 89, 'learning_rate': 0.011897591721351415, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.7375480863170255, 'colsample_bytree': 0.5903351952878976, 'reg_alpha': 0.35268173811828074, 'reg_lambda': 0.15241039939521317, 'n_estimators': 400}. Best is trial 22 with value: 0.4715300193673338.
# [I 2023-07-01 12:11:51,142] Trial 24 finished with value: 0.46029696578437707 and parameters: {'num_leaves': 67, 'learning_rate': 0.019182832336178235, 'max_depth': 4, 'min_child_samples': 18, 'subsample': 0.6852675341041828, 'colsample_bytree': 0.6607532779929552, 'reg_alpha': 0.5373826254580262, 'reg_lambda': 0.2523786819527741, 'n_estimators': 1497}. Best is trial 22 with value: 0.4715300193673338.
# [I 2023-07-01 12:12:09,270] Trial 25 finished with value: 0.4677856681730148 and parameters: {'num_leaves': 88, 'learning_rate': 0.01054966194491112, 'max_depth': 6, 'min_child_samples': 18, 'subsample': 0.5684385821909514, 'colsample_bytree': 0.5437041112933471, 'reg_alpha': 0.48002328517503984, 'reg_lambda': 0.3848086555772281, 'n_estimators': 823}. Best is trial 22 with value: 0.4715300193673338.
# [I 2023-07-01 12:12:13,486] Trial 26 finished with value: 0.4723047127178825 and parameters: {'num_leaves': 93, 'learning_rate': 0.033732565992379906, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.6771907546218131, 'colsample_bytree': 0.5673942158420957, 'reg_alpha': 0.3219214823366314, 'reg_lambda': 0.09256156333374826, 'n_estimators': 320}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:12:37,619] Trial 27 finished with value: 0.4579728857327307 and parameters: {'num_leaves': 95, 'learning_rate': 0.0340966824712404, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.6827241209819458, 'colsample_bytree': 0.5919085664679452, 'reg_alpha': 0.31904732404323344, 'reg_lambda': 0.08538778836547133, 'n_estimators': 1399}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:13:53,479] Trial 28 finished with value: 0.46184635248547456 and parameters: {'num_leaves': 96, 'learning_rate': 0.0168438981642878, 'max_depth': 6, 'min_child_samples': 3, 'subsample': 0.7382399803047116, 'colsample_bytree': 0.6997069099910331, 'reg_alpha': 0.1363190419013166, 'reg_lambda': 0.0687545543320601, 'n_estimators': 2440}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:14:02,762] Trial 29 finished with value: 0.4698515171078115 and parameters: {'num_leaves': 86, 'learning_rate': 0.03172546104889809, 'max_depth': 5, 'min_child_samples': 19, 'subsample': 0.6947613631026127, 'colsample_bytree': 0.6438090293689154, 'reg_alpha': 0.31368164528539694, 'reg_lambda': 0.188335271287888, 'n_estimators': 488}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:14:09,965] Trial 30 finished with value: 0.465203357004519 and parameters: {'num_leaves': 73, 'learning_rate': 0.026641152702543216, 'max_depth': 3, 'min_child_samples': 15, 'subsample': 0.6631308500046206, 'colsample_bytree': 0.6161095811604558, 'reg_alpha': 0.6829874420139393, 'reg_lambda': 0.14598651217553757, 'n_estimators': 1058}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:14:11,117] Trial 31 finished with value: 0.46300839251129755 and parameters: {'num_leaves': 80, 'learning_rate': 0.02239534361367318, 'max_depth': 4, 'min_child_samples': 18, 'subsample': 0.6105510336073687, 'colsample_bytree': 0.5416116987524564, 'reg_alpha': 0.48869273863572404, 'reg_lambda': 0.2721837310517394, 'n_estimators': 102}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:14:14,705] Trial 32 finished with value: 0.4703679793415107 and parameters: {'num_leaves': 91, 'learning_rate': 0.016626159724631683, 'max_depth': 4, 'min_child_samples': 19, 'subsample': 0.6482074823309086, 'colsample_bytree': 0.5760361534329828, 'reg_alpha': 0.37965150573630857, 'reg_lambda': 0.18877874251849325, 'n_estimators': 361}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:15:00,890] Trial 33 finished with value: 0.45371207230471267 and parameters: {'num_leaves': 100, 'learning_rate': 0.02272863862015731, 'max_depth': 4, 'min_child_samples': 17, 'subsample': 0.6994578332663576, 'colsample_bytree': 0.5347265922468216, 'reg_alpha': 0.45985769861781367, 'reg_lambda': 0.10473803614929388, 'n_estimators': 4240}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:15:07,491] Trial 34 finished with value: 0.4679147837314397 and parameters: {'num_leaves': 86, 'learning_rate': 0.029016073013387836, 'max_depth': 3, 'min_child_samples': 16, 'subsample': 0.5947285398723263, 'colsample_bytree': 0.5290240185242717, 'reg_alpha': 0.5614729748595955, 'reg_lambda': 0.29031763257481386, 'n_estimators': 718}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:15:12,103] Trial 35 finished with value: 0.4720464816010329 and parameters: {'num_leaves': 93, 'learning_rate': 0.018146352876924773, 'max_depth': 5, 'min_child_samples': 19, 'subsample': 0.633550026071078, 'colsample_bytree': 0.5725017674279042, 'reg_alpha': 0.41905507884758086, 'reg_lambda': 0.18477548510699304, 'n_estimators': 332}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:15:25,749] Trial 36 finished with value: 0.4697224015493867 and parameters: {'num_leaves': 94, 'learning_rate': 0.014975690377480524, 'max_depth': 5, 'min_child_samples': 19, 'subsample': 0.5556763294373496, 'colsample_bytree': 0.57402032854224, 'reg_alpha': 0.391725310115946, 'reg_lambda': 0.18807560863709788, 'n_estimators': 814}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:15:54,475] Trial 37 finished with value: 0.4671400903808909 and parameters: {'num_leaves': 100, 'learning_rate': 0.01016926740947195, 'max_depth': 6, 'min_child_samples': 20, 'subsample': 0.7274861586895908, 'colsample_bytree': 0.697662095472813, 'reg_alpha': 0.3153312878418633, 'reg_lambda': 0.06116036113542153, 'n_estimators': 1219}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:17:55,855] Trial 38 finished with value: 0.4659780503550678 and parameters: {'num_leaves': 58, 'learning_rate': 0.017658023509390604, 'max_depth': 8, 'min_child_samples': 1, 'subsample': 0.7623613985956477, 'colsample_bytree': 0.6268961702171154, 'reg_alpha': 0.1986829052555704, 'reg_lambda': 0.004363187328908155, 'n_estimators': 4182}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:18:06,516] Trial 39 finished with value: 0.4614590058102001 and parameters: {'num_leaves': 16, 'learning_rate': 0.03738668258404556, 'max_depth': 6, 'min_child_samples': 6, 'subsample': 0.6734466050742786, 'colsample_bytree': 0.6019869837656657, 'reg_alpha': 0.4358865048578827, 'reg_lambda': 0.19095346478943986, 'n_estimators': 603}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:18:35,626] Trial 40 finished with value: 0.4636539703034216 and parameters: {'num_leaves': 91, 'learning_rate': 0.014937865201959477, 'max_depth': 5, 'min_child_samples': 14, 'subsample': 0.6086958224399033, 'colsample_bytree': 0.5640073147019636, 'reg_alpha': 0.2730400986957335, 'reg_lambda': 0.12653509997779935, 'n_estimators': 1719}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:18:39,266] Trial 41 finished with value: 0.46649451258876695 and parameters: {'num_leaves': 76, 'learning_rate': 0.023483810821760254, 'max_depth': 4, 'min_child_samples': 18, 'subsample': 0.6405722429232288, 'colsample_bytree': 0.5249180570507763, 'reg_alpha': 0.4915598244395724, 'reg_lambda': 0.2968781014543391, 'n_estimators': 392}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:18:42,131] Trial 42 finished with value: 0.46752743705616534 and parameters: {'num_leaves': 83, 'learning_rate': 0.019829443691029576, 'max_depth': 4, 'min_child_samples': 17, 'subsample': 0.7147002381974891, 'colsample_bytree': 0.5717831204544519, 'reg_alpha': 0.5907569737931492, 'reg_lambda': 0.21078724249450068, 'n_estimators': 288}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:18:42,751] Trial 43 finished with value: 0.45397030342156225 and parameters: {'num_leaves': 96, 'learning_rate': 0.025081803565328423, 'max_depth': 3, 'min_child_samples': 19, 'subsample': 0.63023822779743, 'colsample_bytree': 0.5483114314394849, 'reg_alpha': 0.40259349570092634, 'reg_lambda': 0.4018298390380027, 'n_estimators': 74}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:18:57,126] Trial 44 finished with value: 0.46752743705616523 and parameters: {'num_leaves': 63, 'learning_rate': 0.014185928888629462, 'max_depth': 5, 'min_child_samples': 20, 'subsample': 0.6635323896830876, 'colsample_bytree': 0.5252994521678941, 'reg_alpha': 0.5209798947397949, 'reg_lambda': 0.15471897541248264, 'n_estimators': 900}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:19:02,337] Trial 45 finished with value: 0.47101355713363463 and parameters: {'num_leaves': 30, 'learning_rate': 0.029365906929063636, 'max_depth': 4, 'min_child_samples': 15, 'subsample': 0.5864800619964762, 'colsample_bytree': 0.5563805304460971, 'reg_alpha': 0.43975720459927053, 'reg_lambda': 0.23367210958110157, 'n_estimators': 227}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:19:06,712] Trial 46 finished with value: 0.4654615881213687 and parameters: {'num_leaves': 23, 'learning_rate': 0.040770949155340706, 'max_depth': 3, 'min_child_samples': 13, 'subsample': 0.5504474847221061, 'colsample_bytree': 0.5974784464319011, 'reg_alpha': 0.44209626535021934, 'reg_lambda': 0.23151630493485317, 'n_estimators': 659}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:19:36,004] Trial 47 finished with value: 0.46107165913492576 and parameters: {'num_leaves': 35, 'learning_rate': 0.028837472290434013, 'max_depth': 7, 'min_child_samples': 15, 'subsample': 0.5839415248098134, 'colsample_bytree': 0.6327043376913264, 'reg_alpha': 0.437282550964849, 'reg_lambda': 0.05835299015730189, 'n_estimators': 1154}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:19:39,334] Trial 48 finished with value: 0.4688185926404132 and parameters: {'num_leaves': 48, 'learning_rate': 0.018504550920423298, 'max_depth': 5, 'min_child_samples': 19, 'subsample': 0.6053460604788746, 'colsample_bytree': 0.5606033440729923, 'reg_alpha': 0.26611923707909463, 'reg_lambda': 0.1004988386816445, 'n_estimators': 223}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:19:56,798] Trial 49 finished with value: 0.4579728857327308 and parameters: {'num_leaves': 24, 'learning_rate': 0.0486880035919583, 'max_depth': 6, 'min_child_samples': 11, 'subsample': 0.5369497094312089, 'colsample_bytree': 0.6165534619543248, 'reg_alpha': 0.38865523177511196, 'reg_lambda': 0.2773057371255797, 'n_estimators': 942}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:20:34,249] Trial 50 finished with value: 0.4535829567462879 and parameters: {'num_leaves': 39, 'learning_rate': 0.031053854764413552, 'max_depth': 3, 'min_child_samples': 16, 'subsample': 0.6248437171828365, 'colsample_bytree': 0.6450445003131103, 'reg_alpha': 0.5359014501502244, 'reg_lambda': 0.1660743299644859, 'n_estimators': 4504}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:20:36,777] Trial 51 finished with value: 0.468302130406714 and parameters: {'num_leaves': 29, 'learning_rate': 0.025257376159618324, 'max_depth': 4, 'min_child_samples': 18, 'subsample': 0.6394332841105975, 'colsample_bytree': 0.5059564898530989, 'reg_alpha': 0.4613067834129605, 'reg_lambda': 0.36161736576266, 'n_estimators': 260}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:20:44,692] Trial 52 finished with value: 0.4652033570045191 and parameters: {'num_leaves': 82, 'learning_rate': 0.02071587202121203, 'max_depth': 4, 'min_child_samples': 17, 'subsample': 0.6654207123924609, 'colsample_bytree': 0.5429821677860183, 'reg_alpha': 0.3546689156140074, 'reg_lambda': 0.22741211783767054, 'n_estimators': 574}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:20:45,901] Trial 53 finished with value: 0.45229180116204004 and parameters: {'num_leaves': 88, 'learning_rate': 0.013815451781470117, 'max_depth': 4, 'min_child_samples': 19, 'subsample': 0.5926431553805565, 'colsample_bytree': 0.5784658446211809, 'reg_alpha': 0.4963656591715873, 'reg_lambda': 0.3086998624168809, 'n_estimators': 82}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:21:32,977] Trial 54 finished with value: 0.45758553905745647 and parameters: {'num_leaves': 92, 'learning_rate': 0.026795733671806245, 'max_depth': 5, 'min_child_samples': 9, 'subsample': 0.6963067242539056, 'colsample_bytree': 0.5171331425905633, 'reg_alpha': 0.6090564084779886, 'reg_lambda': 0.36436305028675237, 'n_estimators': 2938}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:21:37,123] Trial 55 finished with value: 0.47010974822466106 and parameters: {'num_leaves': 71, 'learning_rate': 0.03450438236193286, 'max_depth': 4, 'min_child_samples': 15, 'subsample': 0.6193149326952357, 'colsample_bytree': 0.5000049420102277, 'reg_alpha': 0.4089965864846532, 'reg_lambda': 0.4358747534633645, 'n_estimators': 458}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:21:42,692] Trial 56 finished with value: 0.46739832149774047 and parameters: {'num_leaves': 76, 'learning_rate': 0.013751462680876009, 'max_depth': 4, 'min_child_samples': 20, 'subsample': 0.6575204342042839, 'colsample_bytree': 0.5585560882907776, 'reg_alpha': 0.5650098593398069, 'reg_lambda': 0.2625858431613201, 'n_estimators': 280}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:22:05,916] Trial 57 finished with value: 0.4659780503550678 and parameters: {'num_leaves': 51, 'learning_rate': 0.010035543233016395, 'max_depth': 8, 'min_child_samples': 18, 'subsample': 0.675339433594478, 'colsample_bytree': 0.6055087977058906, 'reg_alpha': 0.5160199158637581, 'reg_lambda': 0.315743754835637, 'n_estimators': 748}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:22:45,557] Trial 58 finished with value: 0.4581020012911556 and parameters: {'num_leaves': 97, 'learning_rate': 0.019471763028056675, 'max_depth': 5, 'min_child_samples': 13, 'subsample': 0.6373324138354817, 'colsample_bytree': 0.5831135649885208, 'reg_alpha': 0.4571305553380231, 'reg_lambda': 0.1266164766414401, 'n_estimators': 2187}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:22:49,138] Trial 59 finished with value: 0.47088444157520976 and parameters: {'num_leaves': 85, 'learning_rate': 0.023168953278057174, 'max_depth': 3, 'min_child_samples': 17, 'subsample': 0.5765485144004799, 'colsample_bytree': 0.5335942997909473, 'reg_alpha': 0.6386043183449366, 'reg_lambda': 0.2177677567421858, 'n_estimators': 570}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:22:52,565] Trial 60 finished with value: 0.471400903808909 and parameters: {'num_leaves': 86, 'learning_rate': 0.028856181658163386, 'max_depth': 3, 'min_child_samples': 19, 'subsample': 0.5658022385033625, 'colsample_bytree': 0.556478076045488, 'reg_alpha': 0.6509292853615899, 'reg_lambda': 0.2070117281041983, 'n_estimators': 544}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:22:59,338] Trial 61 finished with value: 0.46726920593931565 and parameters: {'num_leaves': 86, 'learning_rate': 0.028266883092948898, 'max_depth': 3, 'min_child_samples': 19, 'subsample': 0.5782964236765412, 'colsample_bytree': 0.5444535320415641, 'reg_alpha': 0.6339181467540587, 'reg_lambda': 0.20756110756814547, 'n_estimators': 601}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:23:02,828] Trial 62 finished with value: 0.4695932859909619 and parameters: {'num_leaves': 90, 'learning_rate': 0.03171341834443499, 'max_depth': 3, 'min_child_samples': 20, 'subsample': 0.525286969416234, 'colsample_bytree': 0.5922489770878658, 'reg_alpha': 0.7183649876986987, 'reg_lambda': 0.2442232039613586, 'n_estimators': 470}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:23:12,733] Trial 63 finished with value: 0.4626210458360232 and parameters: {'num_leaves': 82, 'learning_rate': 0.02460163281258102, 'max_depth': 3, 'min_child_samples': 19, 'subsample': 0.5756002077652066, 'colsample_bytree': 0.5587054519959733, 'reg_alpha': 0.7772259153904989, 'reg_lambda': 0.16265361069890205, 'n_estimators': 1119}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:23:20,512] Trial 64 finished with value: 0.4612007746933505 and parameters: {'num_leaves': 86, 'learning_rate': 0.02209626928102296, 'max_depth': 3, 'min_child_samples': 18, 'subsample': 0.6034259797764943, 'colsample_bytree': 0.5196359252170177, 'reg_alpha': 0.5732819938009979, 'reg_lambda': 0.25801314481981125, 'n_estimators': 1294}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:23:28,867] Trial 65 finished with value: 0.4688185926404132 and parameters: {'num_leaves': 93, 'learning_rate': 0.01720723672129123, 'max_depth': 3, 'min_child_samples': 20, 'subsample': 0.5671999768300141, 'colsample_bytree': 0.5375961661962487, 'reg_alpha': 0.6541835522243822, 'reg_lambda': 0.2199739930616413, 'n_estimators': 872}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:23:30,771] Trial 66 finished with value: 0.4686894770819883 and parameters: {'num_leaves': 97, 'learning_rate': 0.0360104686655638, 'max_depth': 4, 'min_child_samples': 17, 'subsample': 0.621728687826717, 'colsample_bytree': 0.5781287729206744, 'reg_alpha': 0.6037043925166677, 'reg_lambda': 0.11925973381978607, 'n_estimators': 186}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:23:35,373] Trial 67 finished with value: 0.4690768237572628 and parameters: {'num_leaves': 67, 'learning_rate': 0.01970276020891898, 'max_depth': 3, 'min_child_samples': 16, 'subsample': 0.5978689853924858, 'colsample_bytree': 0.6030673732828554, 'reg_alpha': 0.3673555845642329, 'reg_lambda': 0.04034754397660036, 'n_estimators': 717}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:24:36,482] Trial 68 finished with value: 0.4595222724338283 and parameters: {'num_leaves': 80, 'learning_rate': 0.012998280886965977, 'max_depth': 5, 'min_child_samples': 18, 'subsample': 0.6511786227137812, 'colsample_bytree': 0.5662484997418791, 'reg_alpha': 0.4205930101728219, 'reg_lambda': 0.2943074196386718, 'n_estimators': 3729}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:24:42,678] Trial 69 finished with value: 0.4679147837314396 and parameters: {'num_leaves': 73, 'learning_rate': 0.03171235883145288, 'max_depth': 4, 'min_child_samples': 19, 'subsample': 0.5860373303545977, 'colsample_bytree': 0.5326346606800679, 'reg_alpha': 0.5413278835061338, 'reg_lambda': 0.08799421210785857, 'n_estimators': 346}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:24:48,954] Trial 70 finished with value: 0.4624919302775985 and parameters: {'num_leaves': 88, 'learning_rate': 0.027371042157149566, 'max_depth': 3, 'min_child_samples': 20, 'subsample': 0.5563422017147776, 'colsample_bytree': 0.5534334242703075, 'reg_alpha': 0.33719015288124693, 'reg_lambda': 0.1885370761426951, 'n_estimators': 1046}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:24:56,468] Trial 71 finished with value: 0.4642995480955455 and parameters: {'num_leaves': 79, 'learning_rate': 0.023363894176986345, 'max_depth': 4, 'min_child_samples': 17, 'subsample': 0.681895888642592, 'colsample_bytree': 0.5132451312701988, 'reg_alpha': 0.47152027782606504, 'reg_lambda': 0.33218087427080023, 'n_estimators': 510}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:24:57,424] Trial 72 finished with value: 0.44686894770819885 and parameters: {'num_leaves': 85, 'learning_rate': 0.016534149645589226, 'max_depth': 4, 'min_child_samples': 16, 'subsample': 0.6374984014764644, 'colsample_bytree': 0.5258630609241931, 'reg_alpha': 0.5126153176586967, 'reg_lambda': 0.25478152573447177, 'n_estimators': 64}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:25:15,183] Trial 73 finished with value: 0.46003873466752737 and parameters: {'num_leaves': 89, 'learning_rate': 0.02197702375770498, 'max_depth': 10, 'min_child_samples': 18, 'subsample': 0.6109665044673435, 'colsample_bytree': 0.5861966240364821, 'reg_alpha': 0.5576663377546899, 'reg_lambda': 0.28448861991086744, 'n_estimators': 363}. Best is trial 26 with value: 0.4723047127178825.
# [I 2023-07-01 12:25:19,327] Trial 74 finished with value: 0.47372498386055517 and parameters: {'num_leaves': 92, 'learning_rate': 0.012022691780349343, 'max_depth': 5, 'min_child_samples': 2, 'subsample': 0.6172227955238407, 'colsample_bytree': 0.5473664356950052, 'reg_alpha': 0.41613721291293393, 'reg_lambda': 0.17017708987979424, 'n_estimators': 242}. Best is trial 74 with value: 0.47372498386055517.
# [I 2023-07-01 12:25:27,977] Trial 75 finished with value: 0.471400903808909 and parameters: {'num_leaves': 93, 'learning_rate': 0.01182860602684091, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.6234377825936167, 'colsample_bytree': 0.5478800713840877, 'reg_alpha': 0.41434468873755015, 'reg_lambda': 0.1446901239539749, 'n_estimators': 217}. Best is trial 74 with value: 0.47372498386055517.
# [I 2023-07-01 12:25:33,154] Trial 76 finished with value: 0.471400903808909 and parameters: {'num_leaves': 95, 'learning_rate': 0.01284144257126228, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.5914382195351355, 'colsample_bytree': 0.5683353828743445, 'reg_alpha': 0.37724047347382045, 'reg_lambda': 0.13646874042037885, 'n_estimators': 193}. Best is trial 74 with value: 0.47372498386055517.
# [I 2023-07-01 12:25:42,855] Trial 77 finished with value: 0.47527437056165267 and parameters: {'num_leaves': 98, 'learning_rate': 0.010726258300226442, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.6186710352439998, 'colsample_bytree': 0.5690642326572914, 'reg_alpha': 0.37843237624912734, 'reg_lambda': 0.14538913425870043, 'n_estimators': 255}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:25:51,083] Trial 78 finished with value: 0.47101355713363463 and parameters: {'num_leaves': 98, 'learning_rate': 0.011851578147751951, 'max_depth': 7, 'min_child_samples': 3, 'subsample': 0.620208343988946, 'colsample_bytree': 0.5720647216802122, 'reg_alpha': 0.29603750821630015, 'reg_lambda': 0.13314743686948577, 'n_estimators': 198}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:26:17,595] Trial 79 finished with value: 0.4615881213686249 and parameters: {'num_leaves': 93, 'learning_rate': 0.013535650451121397, 'max_depth': 6, 'min_child_samples': 3, 'subsample': 0.6307421011938432, 'colsample_bytree': 0.6119254162725997, 'reg_alpha': 0.37037849953872387, 'reg_lambda': 0.08136919703060183, 'n_estimators': 804}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:26:30,721] Trial 80 finished with value: 0.4741123305358296 and parameters: {'num_leaves': 95, 'learning_rate': 0.010130098876405437, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.600844200296619, 'colsample_bytree': 0.5941226222604271, 'reg_alpha': 0.3782320191390358, 'reg_lambda': 0.16746681298182078, 'n_estimators': 395}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:26:43,296] Trial 81 finished with value: 0.4715300193673338 and parameters: {'num_leaves': 95, 'learning_rate': 0.011229757034957507, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.5980284111349911, 'colsample_bytree': 0.5911363096225967, 'reg_alpha': 0.33509887680422956, 'reg_lambda': 0.16765597581856334, 'n_estimators': 381}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:26:55,669] Trial 82 finished with value: 0.4697224015493867 and parameters: {'num_leaves': 100, 'learning_rate': 0.011653497501510807, 'max_depth': 6, 'min_child_samples': 5, 'subsample': 0.6105530262620394, 'colsample_bytree': 0.5898312613502229, 'reg_alpha': 0.3361416311717017, 'reg_lambda': 0.17325184962008902, 'n_estimators': 395}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:27:16,345] Trial 83 finished with value: 0.46649451258876695 and parameters: {'num_leaves': 94, 'learning_rate': 0.015425419939862916, 'max_depth': 6, 'min_child_samples': 2, 'subsample': 0.6522050731538829, 'colsample_bytree': 0.630802452292493, 'reg_alpha': 0.29703440926925323, 'reg_lambda': 0.10572903340697383, 'n_estimators': 675}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:27:35,523] Trial 84 finished with value: 0.4641704325371207 and parameters: {'num_leaves': 98, 'learning_rate': 0.010415239975176344, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.6078758809292509, 'colsample_bytree': 0.5981864502310499, 'reg_alpha': 0.33711406633521784, 'reg_lambda': 0.1606453574089911, 'n_estimators': 457}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:27:46,089] Trial 85 finished with value: 0.46726920593931565 and parameters: {'num_leaves': 91, 'learning_rate': 0.015519392908814895, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.6265099389988001, 'colsample_bytree': 0.5472397370784502, 'reg_alpha': 0.3941372789944704, 'reg_lambda': 0.029428539036836537, 'n_estimators': 310}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:27:47,671] Trial 86 finished with value: 0.455390574564235 and parameters: {'num_leaves': 98, 'learning_rate': 0.01746221690974363, 'max_depth': 6, 'min_child_samples': 7, 'subsample': 0.6634914115504303, 'colsample_bytree': 0.6196176831921095, 'reg_alpha': 0.4189836792740591, 'reg_lambda': 0.05783933384733808, 'n_estimators': 54}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:28:06,275] Trial 87 finished with value: 0.46765655261459005 and parameters: {'num_leaves': 95, 'learning_rate': 0.011901888205696192, 'max_depth': 5, 'min_child_samples': 1, 'subsample': 0.5987394449183148, 'colsample_bytree': 0.5803948296323389, 'reg_alpha': 0.23355545318361837, 'reg_lambda': 0.14290700190772535, 'n_estimators': 973}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:28:32,981] Trial 88 finished with value: 0.46726920593931565 and parameters: {'num_leaves': 91, 'learning_rate': 0.010022804114691041, 'max_depth': 7, 'min_child_samples': 2, 'subsample': 0.5651048712288217, 'colsample_bytree': 0.564849287474847, 'reg_alpha': 0.4003921961039935, 'reg_lambda': 0.10135085618050192, 'n_estimators': 535}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:28:40,619] Trial 89 finished with value: 0.47385409941897993 and parameters: {'num_leaves': 89, 'learning_rate': 0.019127525062496514, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.6441426037374123, 'colsample_bytree': 0.5477143804010097, 'reg_alpha': 0.35129842707795284, 'reg_lambda': 0.1805170554162426, 'n_estimators': 188}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:28:53,028] Trial 90 finished with value: 0.4644286636539702 and parameters: {'num_leaves': 88, 'learning_rate': 0.0184208776122066, 'max_depth': 5, 'min_child_samples': 6, 'subsample': 0.6871216022000503, 'colsample_bytree': 0.6086946700556495, 'reg_alpha': 0.3474620965671684, 'reg_lambda': 0.20053204487979917, 'n_estimators': 727}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:02,520] Trial 91 finished with value: 0.46946417043253713 and parameters: {'num_leaves': 93, 'learning_rate': 0.014781675698217409, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.642982568460652, 'colsample_bytree': 0.5522081696344355, 'reg_alpha': 0.36656254131398663, 'reg_lambda': 0.17355079355477457, 'n_estimators': 323}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:06,537] Trial 92 finished with value: 0.46132989025177534 and parameters: {'num_leaves': 90, 'learning_rate': 0.012194907630640813, 'max_depth': 6, 'min_child_samples': 2, 'subsample': 0.6157067104754252, 'colsample_bytree': 0.5416296765290908, 'reg_alpha': 0.31765787678925295, 'reg_lambda': 0.15404092576672274, 'n_estimators': 135}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:13,686] Trial 93 finished with value: 0.4670109748224661 and parameters: {'num_leaves': 100, 'learning_rate': 0.020503684359783794, 'max_depth': 6, 'min_child_samples': 6, 'subsample': 0.6575331939681415, 'colsample_bytree': 0.5750418034125765, 'reg_alpha': 0.41607249595966, 'reg_lambda': 0.18208637145467757, 'n_estimators': 174}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:39,088] Trial 94 finished with value: 0.46623628147191737 and parameters: {'num_leaves': 96, 'learning_rate': 0.0165351254172605, 'max_depth': 7, 'min_child_samples': 5, 'subsample': 0.627115051305953, 'colsample_bytree': 0.5117295654859458, 'reg_alpha': 0.377749326290411, 'reg_lambda': 0.2113950905832396, 'n_estimators': 599}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:45,644] Trial 95 finished with value: 0.47036797934151064 and parameters: {'num_leaves': 93, 'learning_rate': 0.014320463432492936, 'max_depth': 5, 'min_child_samples': 4, 'subsample': 0.6750557821350007, 'colsample_bytree': 0.5314603379807228, 'reg_alpha': 0.4475921245791311, 'reg_lambda': 0.1084049994295237, 'n_estimators': 414}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:56,557] Trial 96 finished with value: 0.46998063266623624 and parameters: {'num_leaves': 88, 'learning_rate': 0.018836682448586793, 'max_depth': 6, 'min_child_samples': 3, 'subsample': 0.5988089524361031, 'colsample_bytree': 0.5889339908291448, 'reg_alpha': 0.4296345026531223, 'reg_lambda': 0.13726231489731083, 'n_estimators': 279}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:29:57,531] Trial 97 finished with value: 0.4336991607488702 and parameters: {'num_leaves': 83, 'learning_rate': 0.012713446140909879, 'max_depth': 5, 'min_child_samples': 8, 'subsample': 0.6357820186208046, 'colsample_bytree': 0.5498683472453753, 'reg_alpha': 0.3921535864127589, 'reg_lambda': 0.1945371688115004, 'n_estimators': 51}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:30:23,644] Trial 98 finished with value: 0.4604260813428017 and parameters: {'num_leaves': 98, 'learning_rate': 0.015141306691193478, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.6485813373200717, 'colsample_bytree': 0.5973563270368887, 'reg_alpha': 0.46795425299860105, 'reg_lambda': 0.07936877890743224, 'n_estimators': 829}. Best is trial 77 with value: 0.47527437056165267.
# [I 2023-07-01 12:30:45,236] Trial 99 finished with value: 0.4623628147191736 and parameters: {'num_leaves': 95, 'learning_rate': 0.018354917279621547, 'max_depth': 7, 'min_child_samples': 2, 'subsample': 0.58217404192414, 'colsample_bytree': 0.5656836950873424, 'reg_alpha': 0.2924060676640172, 'reg_lambda': 0.11620419760373539, 'n_estimators': 475}. Best is trial 77 with value: 0.47527437056165267.
# Best Parameters: {'num_leaves': 98, 'learning_rate': 0.010726258300226442, 'max_depth': 6, 'min_child_samples': 4, 'subsample': 0.6186710352439998, 'colsample_bytree': 0.5690642326572914, 'reg_alpha': 0.37843237624912734, 'reg_lambda': 0.14538913425870043, 'n_estimators': 255}
